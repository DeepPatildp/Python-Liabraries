# %%
import pandas as pd

# %%
import numpy as nm

# %%
d={"id":[1,2,3,4],"name":["A","B","C","D"]}
df1=pd.DataFrame(d)
d2={"id":[1,2,3,4],"marks":[60,78,56,70]}
df2=pd.DataFrame(d2)
print(df1)
print(df2)
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D
#    id  marks
# 0   1     60
# 1   2     78
# 2   3     56
# 3   4     70

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,6])
y=np.array([0,250])
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]
plt.plot(x,y,marker="o",color="pink")
plt.show()

# %%
plt.bar(x,y,color=["r","b","y"])
plt.show()

# %%
A=df["Points"]
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8788/904373696.py in <module>
# ----> 1 A=df["Points"]
#       2 A
#
# NameError: name 'df' is not defined

# %%
x=[1,2,3,4,5,9]
y=[4,5,6,7,8]
plt.hist(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8788/730224054.py in <module>
#       1 x=[1,2,3,4,5,9]
#       2 y=[4,5,6,7,8]
# ----> 3 plt.hist(A)
#
# NameError: name 'A' is not defined

# %%
plt.boxplot(x,y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23e0ebeccd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23e0ebfe430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23e0ebec940>],
#  'medians': [<matplotlib.lines.Line2D at 0x23e0ebfeb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23e0ebfeee0>],
#  'means': []}

# %%
plt.violinplot(x)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x23e0ea96bb0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x23e0ea96550>,
#  'cmins': <matplotlib.collections.LineCollection at 0x23e0ea89580>,
#  'cbars': <matplotlib.collections.LineCollection at 0x23e0ea89790>}

# %%
import seaborn as sns

# %%
df2=sns.load_dataset('iris')
print(df2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.barplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.histplot(x='sepal_length',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.regplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df2,kind='hex')

# %%
sns.boxplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.violinplot(x='sepal_length',y='sepal_width',data=df2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.factorplot('species',data=df2,kind='count')
# Out:
# C:\Users\john\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\john\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df2)
